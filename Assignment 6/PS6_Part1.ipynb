# %%
import random

##the students in the class
##the most popular names in 2020
students = \
["Oliver",\
"Liam",\
"Ethan",\
"Aiden",\
"Gabriel",\
"Caleb",\
"Elijah",\
"Theodore",\
"Declan",\
"Owen",\
"Elijah",\
"Charlotte",\
"Ava",\
"Amelia",\
"Olivia",\
"Aurora",\
"Violet",\
"Luna",\
"Hazel",\
"Cloe",\
"Aria"
 ]

##needed to build the test results
test_results = []
answers = ['a', 'b', 'c', 'd'] 
num_questions = 3  ##You may change the number for testing, a smaller number
                  ##will made testing the correctness of your code easier

##this code will build a dictionary of length 20 of 
##key - student name
##value - a list of num_questions length of randomly selected
##values from the list answers above
for student in students:
  result = []
  for i in range(num_questions):
    result.append(random.choice(answers))
  test = {}
  test[student] = result
  test_results.append(test)
print("Raw Data: ")
print(test_results)
visited = [False]*len(test_results)
print("Names and Answers of Each Student")
for i in range(0,len(test_results)):
    for key,value in test_results[i].items():
        print(key,value)
print("Names and Answers of Students Who Copied")
for i in range(0,len(test_results)):
    for key,value in test_results[i].items():
        for j in range(0,len(test_results)):
            for key2,value2 in test_results[j].items():
                if  value == value2 and visited[j] == False and key != key2:
                    print(key,value,"copied",key2,value2)
                    visited[j] = True;
# Out:
# Raw Data:
# [{'Oliver': ['b', 'b', 'a']}, {'Liam': ['a', 'd', 'a']}, {'Ethan': ['a', 'c', 'c']}, {'Aiden': ['d', 'd', 'd']}, {'Gabriel': ['d', 'b', 'c']}, {'Caleb': ['a', 'b', 'a']}, {'Elijah': ['b', 'd', 'b']}, {'Theodore': ['c', 'd', 'b']}, {'Declan': ['b', 'a', 'c']}, {'Owen': ['c', 'c', 'b']}, {'Elijah': ['b', 'a', 'a']}, {'Charlotte': ['a', 'c', 'c']}, {'Ava': ['a', 'a', 'c']}, {'Amelia': ['c', 'c', 'b']}, {'Olivia': ['d', 'c', 'c']}, {'Aurora': ['a', 'c', 'b']}, {'Violet': ['a', 'c', 'b']}, {'Luna': ['c', 'a', 'b']}, {'Hazel': ['b', 'a', 'a']}, {'Cloe': ['d', 'c', 'c']}, {'Aria': ['b', 'c', 'd']}]
# Names and Answers of Each Student
# Oliver ['b', 'b', 'a']
# Liam ['a', 'd', 'a']
# Ethan ['a', 'c', 'c']
# Aiden ['d', 'd', 'd']
# Gabriel ['d', 'b', 'c']
# Caleb ['a', 'b', 'a']
# Elijah ['b', 'd', 'b']
# Theodore ['c', 'd', 'b']
# Declan ['b', 'a', 'c']
# Owen ['c', 'c', 'b']
# Elijah ['b', 'a', 'a']
# Charlotte ['a', 'c', 'c']
# Ava ['a', 'a', 'c']
# Amelia ['c', 'c', 'b']
# Olivia ['d', 'c', 'c']
# Aurora ['a', 'c', 'b']
# Violet ['a', 'c', 'b']
# Luna ['c', 'a', 'b']
# Hazel ['b', 'a', 'a']
# Cloe ['d', 'c', 'c']
# Aria ['b', 'c', 'd']
# Names and Answers of Students Who Copied
# Ethan ['a', 'c', 'c'] copied Charlotte ['a', 'c', 'c']
# Owen ['c', 'c', 'b'] copied Amelia ['c', 'c', 'b']
# Elijah ['b', 'a', 'a'] copied Hazel ['b', 'a', 'a']
# Charlotte ['a', 'c', 'c'] copied Ethan ['a', 'c', 'c']
# Amelia ['c', 'c', 'b'] copied Owen ['c', 'c', 'b']
# Olivia ['d', 'c', 'c'] copied Cloe ['d', 'c', 'c']
# Aurora ['a', 'c', 'b'] copied Violet ['a', 'c', 'b']
# Violet ['a', 'c', 'b'] copied Aurora ['a', 'c', 'b']
# Hazel ['b', 'a', 'a'] copied Elijah ['b', 'a', 'a']
# Cloe ['d', 'c', 'c'] copied Olivia ['d', 'c', 'c']
